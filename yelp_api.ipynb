# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pip install yelpapi
# Out:
# Requirement already satisfied: yelpapi in c:\users\nehcr\anaconda3\envs\learn-env\lib\site-packages (2.4.0)
# Requirement already satisfied: requests in c:\users\nehcr\anaconda3\envs\learn-env\lib\site-packages (from yelpapi) (2.24.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\nehcr\anaconda3\envs\learn-env\lib\site-packages (from requests->yelpapi) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\nehcr\anaconda3\envs\learn-env\lib\site-packages (from requests->yelpapi) (1.25.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nehcr\anaconda3\envs\learn-env\lib\site-packages (from requests->yelpapi) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\nehcr\anaconda3\envs\learn-env\lib\site-packages (from requests->yelpapi) (2.10)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install rauth
# Out:
# Requirement already satisfied: rauth in c:\users\nehcr\anaconda3\envs\learn-env\lib\site-packages (0.7.3)
# Requirement already satisfied: requests>=1.2.3 in c:\users\nehcr\anaconda3\envs\learn-env\lib\site-packages (from rauth) (2.24.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\nehcr\anaconda3\envs\learn-env\lib\site-packages (from requests>=1.2.3->rauth) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nehcr\anaconda3\envs\learn-env\lib\site-packages (from requests>=1.2.3->rauth) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\nehcr\anaconda3\envs\learn-env\lib\site-packages (from requests>=1.2.3->rauth) (1.25.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\nehcr\anaconda3\envs\learn-env\lib\site-packages (from requests>=1.2.3->rauth) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fsspec
# Out:
# Requirement already satisfied: fsspec in c:\users\nehcr\anaconda3\envs\learn-env\lib\site-packages (2021.7.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from yelpapi import YelpAPI
import argparse
from pprint import pprint
import requests
import json

# %%
# https://python.gotrained.com/yelp-fusion-api-tutorial/

# %%
api_key='mpM2Cg4D9TcgIj5gtmQb-q5cYQyKtDwxePMi7ie43QcDU2u1TqzUin7MW1yD7Dt2SBfA7yf2xGQ9-Cn5aHkFs5kPQZ668_ZVEG_jMzl80uQ-er4rzjVTvzx1wevvYHYx'
headers = {'Authorization': 'Bearer %s' % api_key}

# %%
url='https://api.yelp.com/v3/businesses/search'
 
# In the dictionary, term can take values like food, cafes or businesses like McDonalds
parameters = {'location':'San Jose', 'term': 'cafe'}

# %%
# Making a get request to the API
req=requests.get(url, params=parameters, headers=headers)
 
# proceed only if the status code is 200
print('The status code is {}'.format(req.status_code))
# Out:
# The status code is 200

# %%
req.json()
# Out:
# {'businesses': [{'id': 'h6vgiIF41x-AWNJ4vpo-_g',
#    'alias': 'paper-moon-cafe-san-jose',
#    'name': 'Paper Moon Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/drTH06Nofihoug1Szsoctg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paper-moon-cafe-san-jose?adjust_creative=9hXN71rkjjtHQ4rR1jQV8A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9hXN71rkjjtHQ4rR1jQV8A',
#    'review_count': 102,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.336886, 'longitude': -121.889982},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '17 N 2nd St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Jose',
#     'zip_code': '95113',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['17 N 2nd St', 'San Jose, CA 95113']},
#    'phone': '+14085474234',
#    'display_phone': '(408) 547-4234',
#    'distance': 2313.475184246511},
#   {'id': 'Xz6-BIQ7GgJ2Vf_cvivAAQ',
#    'alias': 'k-cafe-patisserie-and-tea-house-san-jose-3',
#    'name': 'K Cafe Patisserie & Tea House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZDsm77LEw_WJf-lW3-9GTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/k-cafe-patisserie-and-tea-house-san-jose-3?adjust_creative=9hXN71rkjjtHQ4rR1jQV8A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9hXN71rkjjtHQ4rR1jQV8A',
#    'review_count': 366,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.30953, 'longitude': -121.93215},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '923 S Bascom Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'San Jose',
#     'zip_code': '95128',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['923 S Bascom Ave', 'San Jose, CA 95128']},
#    'phone': '+14089000023',
#    'display_phone': '(408) 900-0023',
#    'distance': 4234.92021430862},
#   {'id': 'Z-_xTpkFMWukHIMpjcXB5A',
#    'alias': 'coffee-and-water-lab-san-jose-2',
#    'name': 'Coffee & Water Lab ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Dgs_ejEa4KQU-n2Z5c5WZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coffee-and-water-lab-san-jose-2?adjust_creative=9hXN71rkjjtHQ4rR1jQV8A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9hXN71rkjjtHQ4rR1jQV8A',
#    'review_count': 84,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'waterstores', 'title': 'Water Stores'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.31562, 'longitude': -121.97651},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '603 Saratoga Ave',
#     'address2': 'Ste 40',
#     'address3': '',
#     'city': 'San Jose',
#     'zip_code': '95129',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['603 Saratoga Ave', 'Ste 40', 'San Jose, CA 95129']},
#    'phone': '+14087803830',
#    'display_phone': '(408) 780-3830',
#    'distance': 8090.0767705992475},
#   {'id': 'X9_bLC143PtN1XT0K7P8iQ',
#    'alias': 'voyager-craft-coffee-santa-clara',
#    'name': 'Voyager Craft Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7-Zqcj5mOSKUynbceAdPHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/voyager-craft-coffee-santa-clara?adjust_creative=9hXN71rkjjtHQ4rR1jQV8A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9hXN71rkjjtHQ4rR1jQV8A',
#    'review_count': 1418,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.3236199, 'longitude': -121.9725281},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '3985 Stevens Creek Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Santa Clara',
#     'zip_code': '95051',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3985 Stevens Creek Blvd', 'Santa Clara, CA 95051']},
#    'phone': '+14082160761',
#    'display_phone': '(408) 216-0761',
#    'distance': 7774.385807805602},
#   {'id': 'lD20F_0ZnlBKqNXhQr0KGQ',
#    'alias': 'spectra-coffee-san-jose',
#    'name': 'Spectra Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AW_ng-a9V0RN8aiugg-8hQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spectra-coffee-san-jose?adjust_creative=9hXN71rkjjtHQ4rR1jQV8A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9hXN71rkjjtHQ4rR1jQV8A',
#    'review_count': 197,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.252056, 'longitude': -121.879368},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '5353 Almaden Expy',
#     'address2': 'Ste 52',
#     'address3': None,
#     'city': 'San Jose',
#     'zip_code': '95118',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['5353 Almaden Expy', 'Ste 52', 'San Jose, CA 95118']},
#    'phone': '+14089138965',
#    'display_phone': '(408) 913-8965',
#    'distance': 7181.487133870007},
#   {'id': 'mLZXUVABNG0TevySSm-gzA',
#    'alias': 'chromatic-coffee-san-jose-4',
#    'name': 'Chromatic Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/fGyOpbD63f66-TNn_Be2fA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chromatic-coffee-san-jose-4?adjust_creative=9hXN71rkjjtHQ4rR1jQV8A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9hXN71rkjjtHQ4rR1jQV8A',
#    'review_count': 156,
#    'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.32, 'longitude': -121.9082},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '460 Lincoln Ave',
#     'address2': 'Ste 10',
#     'address3': '',
#     'city': 'San Jose',
#     'zip_code': '95126',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['460 Lincoln Ave', 'Ste 10', 'San Jose, CA 95126']},
#    'phone': '+14082178583',
#    'display_phone': '(408) 217-8583',
#    'distance': 2067.7310277470406},
#   {'id': 'f4WbbgnN_oIFHssKRImfMA',
#    'alias': 'voyager-craft-coffee-san-jose-2',
#    'name': 'Voyager Craft Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eKj3LcQh3rBm-yI-VVrR8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/voyager-craft-coffee-san-jose-2?adjust_creative=9hXN71rkjjtHQ4rR1jQV8A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9hXN71rkjjtHQ4rR1jQV8A',
#    'review_count': 223,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.3365265, 'longitude': -121.894292},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '87 N San Pedro St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Jose',
#     'zip_code': '95110',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['87 N San Pedro St', 'San Jose, CA 95110']},
#    'phone': '+14088996166',
#    'display_phone': '(408) 899-6166',
#    'distance': 2373.386346491955},
#   {'id': 'mVTd_mqoNNyFwJeINuwlDw',
#    'alias': 'hubs-coffee-san-jose',
#    'name': "Hub's  Coffee",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tLMgp7CYba3-Kb-DzKa9sQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hubs-coffee-san-jose?adjust_creative=9hXN71rkjjtHQ4rR1jQV8A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9hXN71rkjjtHQ4rR1jQV8A',
#    'review_count': 337,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.2500908692612,
#     'longitude': -121.844339291171},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '630 Blossom Hill Rd',
#     'address2': 'Ste 50',
#     'address3': None,
#     'city': 'San  Jose',
#     'zip_code': '95123',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['630 Blossom Hill Rd',
#      'Ste 50',
#      'San  Jose, CA 95123']},
#    'phone': '+14086228304',
#    'display_phone': '(408) 622-8304',
#    'distance': 8214.843222635438},
#   {'id': 'tyr85X7PWdx54LOVzLzjAw',
#    'alias': 'hannah-san-jose',
#    'name': 'Hannah',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UrG5-WU_DrEfeLWRRqcrEQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hannah-san-jose?adjust_creative=9hXN71rkjjtHQ4rR1jQV8A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9hXN71rkjjtHQ4rR1jQV8A',
#    'review_count': 1192,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.33065, 'longitude': -121.9051},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '754 The Alameda',
#     'address2': 'Ste 80',
#     'address3': '',
#     'city': 'San Jose',
#     'zip_code': '95126',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['754 The Alameda', 'Ste 80', 'San Jose, CA 95126']},
#    'phone': '+14089711207',
#    'display_phone': '(408) 971-1207',
#    'distance': 2441.5856153002233},
#   {'id': 'Xtth_852Xe8ZkicsokL-9w',
#    'alias': 'jiaren-cafe-santa-clara-3',
#    'name': 'Jiaren Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/535z3v1Bdhy_p9Tsfrzp_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jiaren-cafe-santa-clara-3?adjust_creative=9hXN71rkjjtHQ4rR1jQV8A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9hXN71rkjjtHQ4rR1jQV8A',
#    'review_count': 248,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.34855903388084,
#     'longitude': -121.94573524108979},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1171 Homestead Rd',
#     'address2': 'Ste 140B',
#     'address3': '',
#     'city': 'Santa Clara',
#     'zip_code': '95050',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1171 Homestead Rd',
#      'Ste 140B',
#      'Santa Clara, CA 95050']},
#    'phone': '+14086573264',
#    'display_phone': '(408) 657-3264',
#    'distance': 6441.34667479857},
#   {'id': '7IeNBZodKmN_4-2hqYP3dg',
#    'alias': 'voltaire-coffee-roasters-san-jose-3',
#    'name': 'Voltaire Coffee Roasters',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Dmm86umIL2-6V7q21oEe6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/voltaire-coffee-roasters-san-jose-3?adjust_creative=9hXN71rkjjtHQ4rR1jQV8A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9hXN71rkjjtHQ4rR1jQV8A',
#    'review_count': 353,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.32981, 'longitude': -121.88677},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '360 S Market St',
#     'address2': 'Ste 80',
#     'address3': '',
#     'city': 'San Jose',
#     'zip_code': '95113',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['360 S Market St', 'Ste 80', 'San Jose, CA 95113']},
#    'phone': '+14087479697',
#    'display_phone': '(408) 747-9697',
#    'distance': 1542.0970045788858},
#   {'id': '27MKze8laNnGbmfV2HrZFQ',
#    'alias': 'paper-moon-coffee-santa-clara',
#    'name': 'Paper Moon Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/aP1qemw_TAkzxooxJLNZsw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paper-moon-coffee-santa-clara?adjust_creative=9hXN71rkjjtHQ4rR1jQV8A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9hXN71rkjjtHQ4rR1jQV8A',
#    'review_count': 122,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 37.323959, 'longitude': -121.994339},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '5237 Stevens Creek Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Santa Clara',
#     'zip_code': '95051',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['5237 Stevens Creek Blvd', 'Santa Clara, CA 95051']},
#    'phone': '+14082484500',
#    'display_phone': '(408) 248-4500',
#    'distance': 9710.370257071649},
#   {'id': 'MHLAiMZeZND30AFf2TVVDQ',
#    'alias': 'caffe-bene-san-jose',
#    'name': 'Caffe Bene',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dxmST98-xzYOj41shv_kdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caffe-bene-san-jose?adjust_creative=9hXN71rkjjtHQ4rR1jQV8A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9hXN71rkjjtHQ4rR1jQV8A',
#    'review_count': 263,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.412773, 'longitude': -121.937613},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '181 E Tasman Dr',
#     'address2': 'Ste 80',
#     'address3': '',
#     'city': 'San Jose',
#     'zip_code': '95134',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['181 E Tasman Dr', 'Ste 80', 'San Jose, CA 95134']},
#    'phone': '+16692849959',
#    'display_phone': '(669) 284-9959',
#    'distance': 11670.695716356468},
#   {'id': 'trg4LRKhdzx_zO_Qo_a13A',
#    'alias': 'cafe-paradise-san-jose',
#    'name': 'Cafe Paradise',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/M-uuQQGVGGnhewHGEMrnLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-paradise-san-jose?adjust_creative=9hXN71rkjjtHQ4rR1jQV8A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9hXN71rkjjtHQ4rR1jQV8A',
#    'review_count': 97,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'hookah_bars', 'title': 'Hookah Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.30065, 'longitude': -121.85764},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2400 Monterey Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Jose',
#     'zip_code': '95111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2400 Monterey Rd', 'San Jose, CA 95111']},
#    'phone': '+14085640735',
#    'display_phone': '(408) 564-0735',
#    'distance': 2975.694014493371},
#   {'id': 'HnMZ-pm4P3sUnASbg05ZlQ',
#    'alias': 'yeganeh-bakery-and-kafe-unik-san-jose-4',
#    'name': 'Yeganeh Bakery & Kafe Unik',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uUTdRr9PYyo8tJ56CWcnhg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yeganeh-bakery-and-kafe-unik-san-jose-4?adjust_creative=9hXN71rkjjtHQ4rR1jQV8A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9hXN71rkjjtHQ4rR1jQV8A',
#    'review_count': 1008,
#    'categories': [{'alias': 'persian', 'title': 'Persian/Iranian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.3234875728828,
#     'longitude': -121.954808267698},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '3275 Stevens Creek Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Jose',
#     'zip_code': '95117',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3275 Stevens Creek Blvd', 'San Jose, CA 95117']},
#    'phone': '+14086661229',
#    'display_phone': '(408) 666-1229',
#    'distance': 6215.832061449465},
#   {'id': 'r49CWbLD6ilNlr1dsVWpyw',
#    'alias': 'phin-bar-san-jose-3',
#    'name': 'Phin Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6XuIXSIFdYlb0WCZyG_EMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/phin-bar-san-jose-3?adjust_creative=9hXN71rkjjtHQ4rR1jQV8A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9hXN71rkjjtHQ4rR1jQV8A',
#    'review_count': 40,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 37.39253, 'longitude': -121.89335},
#    'transactions': [],
#    'location': {'address1': '1161 Ringwood Cour',
#     'address2': 'Ste-100',
#     'address3': '',
#     'city': 'San Jose',
#     'zip_code': '95035',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1161 Ringwood Cour',
#      'Ste-100',
#      'San Jose, CA 95035']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 8533.960043275662},
#   {'id': 'DuC42Y2rYaNMTRwRUCGzoA',
#    'alias': 'nirvana-soul-san-jose',
#    'name': 'Nirvana Soul',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qwc3b-scJS-N1YQGWmCbBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nirvana-soul-san-jose?adjust_creative=9hXN71rkjjtHQ4rR1jQV8A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9hXN71rkjjtHQ4rR1jQV8A',
#    'review_count': 280,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 37.331167, 'longitude': -121.887016},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '315 S 1st St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Jose',
#     'zip_code': '95113',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['315 S 1st St', 'San Jose, CA 95113']},
#    'phone': '+14085646617',
#    'display_phone': '(408) 564-6617',
#    'distance': 1642.0233263502596},
#   {'id': 'ZccdVU4To-Caz6c3DXPp7A',
#    'alias': 'joyheart-cafe-san-jose-2',
#    'name': 'Joyheart Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hyiPGy3sc9qT80rBMBrkwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joyheart-cafe-san-jose-2?adjust_creative=9hXN71rkjjtHQ4rR1jQV8A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9hXN71rkjjtHQ4rR1jQV8A',
#    'review_count': 44,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'taiwanese', 'title': 'Taiwanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.38768, 'longitude': -121.90025},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1344 Ridder Park Dr',
#     'address2': '',
#     'address3': None,
#     'city': 'San Jose',
#     'zip_code': '95131',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1344 Ridder Park Dr', 'San Jose, CA 95131']},
#    'phone': '+14086496134',
#    'display_phone': '(408) 649-6134',
#    'distance': 8024.636235849387},
#   {'id': 'uN2L_3jCXR3smvxIR7Ha4g',
#    'alias': 'bloom-tea-house-san-jose-2',
#    'name': 'Bloom Tea House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GpD9EVfFfeYsIiO6Wqz3dw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bloom-tea-house-san-jose-2?adjust_creative=9hXN71rkjjtHQ4rR1jQV8A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9hXN71rkjjtHQ4rR1jQV8A',
#    'review_count': 29,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.3243, 'longitude': -121.79793},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '2850 Quimby Rd',
#     'address2': 'Ste 125',
#     'address3': '',
#     'city': 'San Jose',
#     'zip_code': '95148',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2850 Quimby Rd', 'Ste 125', 'San Jose, CA 95148']},
#    'phone': '+14086747399',
#    'display_phone': '(408) 674-7399',
#    'distance': 7709.41228495431},
#   {'id': '0--Hrzm3Ah-LzES-XtSWLw',
#    'alias': 'ijava-cafe-san-jose-4',
#    'name': 'iJava Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Wz8P4HpZ0GmbA_inIHabEQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ijava-cafe-san-jose-4?adjust_creative=9hXN71rkjjtHQ4rR1jQV8A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9hXN71rkjjtHQ4rR1jQV8A',
#    'review_count': 630,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.3261211279172,
#     'longitude': -121.894719195483},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '387 Delmas Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'San Jose',
#     'zip_code': '95126',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['387 Delmas Ave', 'San Jose, CA 95126']},
#    'phone': '+14087539732',
#    'display_phone': '(408) 753-9732',
#    'distance': 1370.0084019878}],
#  'total': 1200,
#  'region': {'center': {'longitude': -121.88507080078125,
#    'latitude': 37.31648115417059}}}

# %%
def getbus(params):
    response = requests.get(url, headers = headers, params = parameters)
    data = req.json()['businesses']
    names = []
    ratings = []
    pricing = []
    cnt = []
    address = []
    for i in range(len(data)):
        names.append(data[i]['name'])
        ratings.append(data[i]['rating'])
        address.append(data[i]['location']['address1'])
        try: 
            pricing.append(len(data[i]['price']))
        except: 
            pricing.append(None)
        cnt.append(data[i]['review_count'])
    bus = {'name': names, 'rating': ratings, 'pricing': pricing, 'num_reviews': cnt, 'street_address': address}
    return pd.DataFrame(bus)

# %%
getbus(parameters)
# Out:
#                              name  rating  pricing  num_reviews  \
# 0                 Paper Moon Cafe     4.5      NaN          102
# 1   K Cafe Patisserie & Tea House     4.0      2.0          366
# 2             Coffee & Water Lab      4.5      2.0           84
# 3            Voyager Craft Coffee     4.5      1.0         1418
# 4                  Spectra Coffee     4.5      2.0          197
# 5                Chromatic Coffee     4.5      1.0          156
# 6            Voyager Craft Coffee     4.5      1.0          223
# 7                   Hub's  Coffee     4.0      1.0          337
# 8                          Hannah     4.5      2.0         1192
# 9                     Jiaren Cafe     4.5      2.0          248
# 10       Voltaire Coffee Roasters     4.5      2.0          353
# 11              Paper Moon Coffee     3.5      1.0          122
# 12                     Caffe Bene     4.0      2.0          263
# 13                  Cafe Paradise     4.0      2.0           97
# 14     Yeganeh Bakery & Kafe Unik     4.5      2.0         1008
# 15                       Phin Bar     5.0      NaN           40
# 16                   Nirvana Soul     5.0      2.0          280
# 17                  Joyheart Cafe     4.5      2.0           44
# 18                Bloom Tea House     4.5      1.0           29
# 19                     iJava Cafe     4.5      1.0          630
#
#              street_address
# 0               17 N 2nd St
# 1          923 S Bascom Ave
# 2          603 Saratoga Ave
# 3   3985 Stevens Creek Blvd
# 4         5353 Almaden Expy
# 5           460 Lincoln Ave
# 6         87 N San Pedro St
# 7       630 Blossom Hill Rd
# 8           754 The Alameda
# 9         1171 Homestead Rd
# 10          360 S Market St
# 11  5237 Stevens Creek Blvd
# 12          181 E Tasman Dr
# 13         2400 Monterey Rd
# 14  3275 Stevens Creek Blvd
# 15       1161 Ringwood Cour
# 16             315 S 1st St
# 17      1344 Ridder Park Dr
# 18           2850 Quimby Rd
# 19           387 Delmas Ave

# %%
# https://github.com/gfairchild/yelpapi/blob/master/examples/examples.py
